# %% [markdown]
# TASK 2 - DATA COLLECTION
# The real-time data from the api was collected for a period of 5 hours for weekdays and weekends to address intresting questions about the biking system in dublin.
# Data was collected every 15minutes on weekdays and weekends.
# pd.concat() function was used to merge the dataframes created for both weekdays and weekends to have two files ready for the explratory analysis in task 3.

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

# %%
url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

# %%
bikes = url + key

# %%
response = requests.get(bikes)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 113

# %%
df = pd.DataFrame(data)
df.columns
# Out:
# Index(['number', 'contract_name', 'name', 'address', 'position', 'banking',
#        'bonus', 'bike_stands', 'available_bike_stands', 'available_bikes',
#        'status', 'last_update'],
#       dtype='object')

# %%
df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]
# Out:
#                          name               dates
# 59          MOLESWORTH STREET 2022-12-08 15:17:53
# 111     LEINSTER STREET SOUTH 2022-12-08 15:17:52
# 66           GRAND CANAL DOCK 2022-12-08 15:17:52
# 39           CHARLEMONT PLACE 2022-12-08 15:17:49
# 31       MERRION SQUARE SOUTH 2022-12-08 15:17:45
# ..                        ...                 ...
# 14     FREDERICK STREET SOUTH 2022-12-08 15:09:45
# 101  ST JAMES HOSPITAL (LUAS) 2022-12-08 15:09:37
# 87           HARDWICKE STREET 2022-12-08 15:09:08
# 45              HERBERT PLACE 2022-12-08 15:09:02
# 8               PEARSE STREET 2022-12-08 15:08:21
#
# [113 rows x 2 columns]

# %%
df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

# %%
bikes = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])

# %%
bikes.to_csv("dublin_bikes.csv")

# %% [markdown]
# call weekday file 1

# %%
pd.read_csv("dublin_bikes.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 2

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes1 = url + key

response = requests.get(bikes1)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes1 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes1.to_csv("dublin_bikes1.csv")

pd.read_csv("dublin_bikes1.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 3

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes2 = url + key

response = requests.get(bikes2)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes2 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes2.to_csv("dublin_bikes2.csv")

pd.read_csv("dublin_bikes2.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 4

# %%
bike1 = pd.read_csv("dublin_bike1")
bike2 = pd.read_csv("dublin_bike2")


pd.concat

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes3 = url + key

response = requests.get(bikes3)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes3 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes3.to_csv("dublin_bikes3.csv")

pd.read_csv("dublin_bikes3.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 5

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes4 = url + key

response = requests.get(bikes4)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes4 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes4.to_csv("dublin_bikes4.csv")

pd.read_csv("dublin_bikes4.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 6

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes5 = url + key

response = requests.get(bikes5)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes5 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes5.to_csv("dublin_bikes5.csv")

pd.read_csv("dublin_bikes5.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 7

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes6 = url + key

response = requests.get(bikes6)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes6 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes6.to_csv("dublin_bikes6.csv")

pd.read_csv("dublin_bikes6.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 8

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes7 = url + key

response = requests.get(bikes7)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes7 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes7.to_csv("dublin_bikes7.csv")

pd.read_csv("dublin_bikes7.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 9

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes8 = url + key

response = requests.get(bikes8)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes8 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes8.to_csv("dublin_bikes8.csv")

pd.read_csv("dublin_bikes8.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekday file 10

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes9 = url + key

response = requests.get(bikes9)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes9 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes9.to_csv("dublin_bikes9.csv")

pd.read_csv("dublin_bikes9.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# use concat function to merge files for dublin bikes on weekdays

# %%
bike  = pd.read_csv("dublin_bikes.csv")
bike1 = pd.read_csv("dublin_bikes1.csv")
bike2 = pd.read_csv("dublin_bikes2.csv")
bike3 = pd.read_csv("dublin_bikes3.csv")
bike4 = pd.read_csv("dublin_bikes4.csv")
bike5 = pd.read_csv("dublin_bikes5.csv")
bike6 = pd.read_csv("dublin_bikes6.csv")
bike7 = pd.read_csv("dublin_bikes7.csv")
bike8 = pd.read_csv("dublin_bikes8.csv")
bike9 = pd.read_csv("dublin_bikes9.csv")

weekday_dublin_bike = pd.concat([bike,bike1,bike2,bike3,bike4,bike5,bike6,bike7,bike8,bike9], ignore_index = True)

# %%
weekday_dublin_bike
# Out:
#       Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0              0      42        dublin        SMITHFIELD NORTH
# 1              1      30        dublin    PARNELL SQUARE NORTH
# 2              2      54        dublin          CLONMEL STREET
# 3              3     108        dublin           AVONDALE ROAD
# 4              4      20        dublin       JAMES STREET EAST
# ...          ...     ...           ...                     ...
# 1125         108      39        dublin          WILTON TERRACE
# 1126         109      83        dublin              EMMET ROAD
# 1127         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 1128         111      21        dublin   LEINSTER STREET SOUTH
# 1129         112      88        dublin         BLACKHALL PLACE
#
#                      ADDRESS  \
# 0           Smithfield North
# 1       Parnell Square North
# 2             Clonmel Street
# 3              Avondale Road
# 4          James Street East
# ...

# %% [markdown]
# call weekend file 1

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd = url + key

response = requests.get(bikes_wknd)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd.to_csv("dublin_bikes_wknd.csv")

pd.read_csv("dublin_bikes_wknd.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 2

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd1 = url + key

response = requests.get(bikes_wknd1)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd1 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd1.to_csv("dublin_bikes_wknd1.csv")

pd.read_csv("dublin_bikes_wknd1.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 3

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd2 = url + key

response = requests.get(bikes_wknd2)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd2 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd2.to_csv("dublin_bikes_wknd2.csv")

pd.read_csv("dublin_bikes_wknd2.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 4

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd3 = url + key

response = requests.get(bikes_wknd3)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd3 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd3.to_csv("dublin_bikes_wknd3.csv")

pd.read_csv("dublin_bikes_wknd3.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 5

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd4 = url + key

response = requests.get(bikes_wknd4)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd4 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd4.to_csv("dublin_bikes_wknd4.csv")

pd.read_csv("dublin_bikes_wknd4.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 6

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd5 = url + key

response = requests.get(bikes_wknd5)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd5 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd5.to_csv("dublin_bikes_wknd5.csv")

pd.read_csv("dublin_bikes_wknd5.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 7

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd6 = url + key

response = requests.get(bikes_wknd6)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd6 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd6.to_csv("dublin_bikes_wknd6.csv")

pd.read_csv("dublin_bikes_wknd6.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 8

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd7 = url + key

response = requests.get(bikes_wknd7)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd7 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd7.to_csv("dublin_bikes_wknd7.csv")

pd.read_csv("dublin_bikes_wknd7.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 9

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd8 = url + key

response = requests.get(bikes_wknd8)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd8 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd8.to_csv("dublin_bikes_wknd8.csv")

pd.read_csv("dublin_bikes_wknd8.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# call weekend file 10

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import warnings
warnings.filterwarnings("ignore")
import requests
import json

url = 'https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey='
key = 'e6deab272dd96e462dae05cd7b5e5f57ada941d4'

bikes_wknd9 = url + key

response = requests.get(bikes_wknd9)

response

data = response.json()

type(data)

len(data)

df = pd.DataFrame(data)
df.columns

df['dates'] = df.iloc[:,11].apply(pd.Timestamp, unit = 'ms')
df.sort_values('dates', ascending = False) [['name', 'dates']]

df1 = df.rename(columns = {"number": "NUMBER", "contract_name":"CONTRACT NAME", "name":"NAME", "address":"ADDRESS","position":"POSITION","banking":"BANKING",
       "bonus":"BONUS","latitude":"LATITUDE", "longitude":"LONGITUDE","bike_stands":"BIKE STANDS","available_bike_stands":"AVAILABLE BIKE STANDS","available_bikes":"AVAILABLE BIKES",
       "status":"STATUS","last_update":"LAST UPDATE","dates":"DATES"})

bikes_wknd9 = pd.DataFrame(df1,columns =['NUMBER', 'CONTRACT NAME', 'NAME', 'ADDRESS', 'POSITION', 'BANKING',
       'BONUS','BIKE STANDS', 'AVAILABLE BIKE STANDS', 'AVAILABLE BIKES',
       'STATUS', 'LAST UPDATE', 'DATES'])
                     

bikes_wknd9.to_csv("dublin_bikes_wknd9.csv")

pd.read_csv("dublin_bikes_wknd9.csv")
# Out:
#      Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0             0      42        dublin        SMITHFIELD NORTH
# 1             1      30        dublin    PARNELL SQUARE NORTH
# 2             2      54        dublin          CLONMEL STREET
# 3             3     108        dublin           AVONDALE ROAD
# 4             4      20        dublin       JAMES STREET EAST
# ..          ...     ...           ...                     ...
# 108         108      39        dublin          WILTON TERRACE
# 109         109      83        dublin              EMMET ROAD
# 110         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 111         111      21        dublin   LEINSTER STREET SOUTH
# 112         112      88        dublin         BLACKHALL PLACE
#
#                     ADDRESS  \
# 0          Smithfield North
# 1      Parnell Square North
# 2            Clonmel Street
# 3             Avondale Road
# 4         James Street East
# ..                      ...
# ...

# %% [markdown]
# use concat to merge all files for dublin weekend bikes

# %%
wknd_bike  = pd.read_csv("dublin_bikes_wknd.csv")
wknd_bike1 = pd.read_csv("dublin_bikes_wknd1.csv")
wknd_bike2 = pd.read_csv("dublin_bikes_wknd2.csv")
wknd_bike3 = pd.read_csv("dublin_bikes_wknd3.csv")
wknd_bike4 = pd.read_csv("dublin_bikes_wknd4.csv")
wknd_bike5 = pd.read_csv("dublin_bikes_wknd5.csv")
wknd_bike6 = pd.read_csv("dublin_bikes_wknd6.csv")
wknd_bike7 = pd.read_csv("dublin_bikes_wknd7.csv")
wknd_bike8 = pd.read_csv("dublin_bikes_wknd8.csv")
wknd_bike9 = pd.read_csv("dublin_bikes_wknd9.csv")

wknd_dublin_bike = pd.concat([wknd_bike,wknd_bike1,wknd_bike2,wknd_bike3,wknd_bike4,wknd_bike5,wknd_bike6,wknd_bike7,wknd_bike8,wknd_bike9], ignore_index = True)
wknd_dublin_bike
# Out:
#       Unnamed: 0  NUMBER CONTRACT NAME                    NAME  \
# 0              0      42        dublin        SMITHFIELD NORTH
# 1              1      30        dublin    PARNELL SQUARE NORTH
# 2              2      54        dublin          CLONMEL STREET
# 3              3     108        dublin           AVONDALE ROAD
# 4              4      20        dublin       JAMES STREET EAST
# ...          ...     ...           ...                     ...
# 1125         108      39        dublin          WILTON TERRACE
# 1126         109      83        dublin              EMMET ROAD
# 1127         110      92        dublin  HEUSTON BRIDGE (NORTH)
# 1128         111      21        dublin   LEINSTER STREET SOUTH
# 1129         112      88        dublin         BLACKHALL PLACE
#
#                      ADDRESS  \
# 0           Smithfield North
# 1       Parnell Square North
# 2             Clonmel Street
# 3              Avondale Road
# 4          James Street East
# ...

# %% [markdown]
# save merged weekend dublin file as csv

# %%
wknd_dublin_bike.to_csv("wknd_dublin_bike.csv")

pd.read_csv("wknd_dublin_bike.csv")
# Out:
#       Unnamed: 0  Unnamed: 0.1  NUMBER CONTRACT NAME                    NAME  \
# 0              0             0      42        dublin        SMITHFIELD NORTH
# 1              1             1      30        dublin    PARNELL SQUARE NORTH
# 2              2             2      54        dublin          CLONMEL STREET
# 3              3             3     108        dublin           AVONDALE ROAD
# 4              4             4      20        dublin       JAMES STREET EAST
# ...          ...           ...     ...           ...                     ...
# 1125        1125           108      39        dublin          WILTON TERRACE
# 1126        1126           109      83        dublin              EMMET ROAD
# 1127        1127           110      92        dublin  HEUSTON BRIDGE (NORTH)
# 1128        1128           111      21        dublin   LEINSTER STREET SOUTH
# 1129        1129           112      88        dublin         BLACKHALL PLACE
#
#                      ADDRESS  \
# ...

# %% [markdown]
# save merged weekday dublin file as csv

# %%
weekday_dublin_bike.to_csv("weekday_dublin_bike.csv")

pd.read_csv("weekday_dublin_bike.csv")
# Out:
#       Unnamed: 0  Unnamed: 0.1  NUMBER CONTRACT NAME                    NAME  \
# 0              0             0      42        dublin        SMITHFIELD NORTH
# 1              1             1      30        dublin    PARNELL SQUARE NORTH
# 2              2             2      54        dublin          CLONMEL STREET
# 3              3             3     108        dublin           AVONDALE ROAD
# 4              4             4      20        dublin       JAMES STREET EAST
# ...          ...           ...     ...           ...                     ...
# 1125        1125           108      39        dublin          WILTON TERRACE
# 1126        1126           109      83        dublin              EMMET ROAD
# 1127        1127           110      92        dublin  HEUSTON BRIDGE (NORTH)
# 1128        1128           111      21        dublin   LEINSTER STREET SOUTH
# 1129        1129           112      88        dublin         BLACKHALL PLACE
#
#                      ADDRESS  \
# ...
